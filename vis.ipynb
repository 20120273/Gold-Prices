# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
df = pd.read_csv('gold_clean.csv')
#df.head()
df
# Out:
#       Unnamed: 0        Date    Open    High     Low   Close  Volume Currency
# 0              0  2000-01-04   289.5   289.5   280.0   283.7   21621      USD
# 1              1  2000-01-05   283.7   285.0   281.0   282.1   25448      USD
# 2              2  2000-01-06   281.6   282.8   280.2   282.4   19055      USD
# 3              3  2000-01-07   282.5   284.5   282.0   282.9   11266      USD
# 4              4  2000-01-10   282.4   283.9   281.8   282.7   30603      USD
# ...          ...         ...     ...     ...     ...     ...     ...      ...
# 5688        5697  2022-08-26  1771.8  1772.3  1746.2  1749.8  176904      USD
# 5689        5698  2022-08-29  1748.4  1757.9  1731.4  1749.7  156220      USD
# 5690        5699  2022-08-30  1749.8  1752.8  1732.9  1736.3  130664      USD
# 5691        5700  2022-08-31  1735.5  1738.0  1720.6  1726.2  176731      USD
# 5692        5701  2022-09-01  1723.0  1723.0  1699.1  1709.3  198618      USD
#
# [5693 rows x 8 columns]

# %% [markdown]
# <h3 style="color: #8DEEEE;"><strong>Trực quan hóa các mối quan hệ của dữ liệu</strong></h3>

# %%
fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

fig.show()

# %% [markdown]
# #### **Sử dụng biểu đồ hình nến để trực quan về giá vàng**
#
# - **Biểu đồ hình nến** (_Candlestick Chart_), hay còn thường được gọi là biểu đồ nến Nhật, mô hình nến, là một loại biểu đồ tài chính dùng để mô tả chuyển động giá của đối tượngn dựa trên mô hình giá trong quá khứ.
# - Biểu đồ hình nến có ý nghĩa vô cùng to lớn trong giao dịch tài chính nói chung và mua bán vàng nói riêng. Chỉ một biểu đồ đơn thuần sẽ cung cấp rất nhiều thông tin quan trọng về thị trường.
# - _Trục X_ nằm ngang biểu thị thời gian. Thời gian hiển thị ở trục X phụ thuộc vào khung thời gian được lựa chọn để phân tích. Nếu khung thời gian là 1D thì mỗi cây nến sẽ biểu thị mức giá dao động trong 1 ngày. 1H thì mỗi cây nến sẽ biểu thị mức giá giao động trong 1 giờ.
# - _Trục Y_ thẳng đứng biểu thị giá. Các mức giá biến động trong một khoảng thời gian nhất định.
# - Theo dataset về giá vàng đã chọn, việc lựa chọn biểu đồ nến là phù hợp, cho phép người dùng nhận ra các xu hướng, mức độ biến động và sự thay đổi trong giá cả của việc giao dịch vàng trong suốt khoảng thời gian nhất định. Bằng cách sử dụng biểu đồ hình nến, người sử dụng có thể dễ dàng so sánh giá trị cao và giá trị thấp của giá vàng trong một ngày giao dịch cụ thể.
#
#
# ##### **_Nhận xét:_**
# +

# %% [markdown]
# Đoạn code trên có ý nghĩa là bạn đang sử dụng thư viện plotly để vẽ một biểu đồ candlestick (nến) từ dữ liệu về giá vàng. Biểu đồ candlestick là một loại biểu đồ tài chính mô tả giá mở cửa, giá cao nhất, giá thấp nhất và giá đóng cửa của một khoảng thời gian cho trước1. Các hộp biểu diễn sự chênh lệch giữa giá mở cửa và giá đóng cửa, còn các đường biểu diễn sự chênh lệch giữa giá cao nhất và giá thấp nhất. Các điểm dữ liệu có giá đóng cửa cao hơn giá mở cửa được gọi là tăng (increasing), còn các điểm dữ liệu có giá đóng cửa thấp hơn giá mở cửa được gọi là giảm (decreasing). Mặc định, các nến tăng có màu xanh lá cây, còn các nến giảm có màu đỏ1.
#
# Trong đoạn code trên, bạn đã nhập thư viện plotly.graph_objects với bí danh go và thư viện pandas với bí danh pd. Sau đó, bạn đã đọc dữ liệu từ một tập tin csv trên internet bằng phương thức pd.read_csv và lưu vào biến df. Dữ liệu này chứa các thông tin về ngày, giá mở cửa, giá cao nhất, giá thấp nhất và giá đóng cửa của vàng. Tiếp theo, bạn đã tạo một đối tượng Figure bằng phương thức go.Figure và truyền vào một danh sách dữ liệu bao gồm một đối tượng Candlestick. Đối tượng Candlestick này có các thuộc tính x, open, high, low và close được lấy từ các cột tương ứng trong biến df. Cuối cùng, bạn đã hiển thị biểu đồ bằng phương thức fig.show().

# %%
df.describe().T.style.set_properties(**{"background-color": "#006600", "font-size" : "14px",
                                        "color": "#ffffff", "border-radius" : "1px", "border": "1.5px solid black"})
# Out:
# <style type="text/css">
# #T_aca0e_row0_col0, #T_aca0e_row0_col1, #T_aca0e_row0_col2, #T_aca0e_row0_col3, #T_aca0e_row0_col4, #T_aca0e_row0_col5, #T_aca0e_row0_col6, #T_aca0e_row0_col7, #T_aca0e_row1_col0, #T_aca0e_row1_col1, #T_aca0e_row1_col2, #T_aca0e_row1_col3, #T_aca0e_row1_col4, #T_aca0e_row1_col5, #T_aca0e_row1_col6, #T_aca0e_row1_col7, #T_aca0e_row2_col0, #T_aca0e_row2_col1, #T_aca0e_row2_col2, #T_aca0e_row2_col3, #T_aca0e_row2_col4, #T_aca0e_row2_col5, #T_aca0e_row2_col6, #T_aca0e_row2_col7, #T_aca0e_row3_col0, #T_aca0e_row3_col1, #T_aca0e_row3_col2, #T_aca0e_row3_col3, #T_aca0e_row3_col4, #T_aca0e_row3_col5, #T_aca0e_row3_col6, #T_aca0e_row3_col7, #T_aca0e_row4_col0, #T_aca0e_row4_col1, #T_aca0e_row4_col2, #T_aca0e_row4_col3, #T_aca0e_row4_col4, #T_aca0e_row4_col5, #T_aca0e_row4_col6, #T_aca0e_row4_col7, #T_aca0e_row5_col0, #T_aca0e_row5_col1, #T_aca0e_row5_col2, #T_aca0e_row5_col3, #T_aca0e_row5_col4, #T_aca0e_row5_col5, #T_aca0e_row5_col6, #T_aca0e_row5_col7 {
# ...
