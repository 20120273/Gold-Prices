# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
df = pd.read_csv('gold_clean.csv')
#df.head()
df
# Out:
#       Unnamed: 0        Date    Open    High     Low   Close  Volume Currency
# 0              0  2000-01-04   289.5   289.5   280.0   283.7   21621      USD
# 1              1  2000-01-05   283.7   285.0   281.0   282.1   25448      USD
# 2              2  2000-01-06   281.6   282.8   280.2   282.4   19055      USD
# 3              3  2000-01-07   282.5   284.5   282.0   282.9   11266      USD
# 4              4  2000-01-10   282.4   283.9   281.8   282.7   30603      USD
# ...          ...         ...     ...     ...     ...     ...     ...      ...
# 5688        5697  2022-08-26  1771.8  1772.3  1746.2  1749.8  176904      USD
# 5689        5698  2022-08-29  1748.4  1757.9  1731.4  1749.7  156220      USD
# 5690        5699  2022-08-30  1749.8  1752.8  1732.9  1736.3  130664      USD
# 5691        5700  2022-08-31  1735.5  1738.0  1720.6  1726.2  176731      USD
# 5692        5701  2022-09-01  1723.0  1723.0  1699.1  1709.3  198618      USD
#
# [5693 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5693 entries, 0 to 5692
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5693 non-null   int64
#  1   Date        5693 non-null   object
#  2   Open        5693 non-null   float64
#  3   High        5693 non-null   float64
#  4   Low         5693 non-null   float64
#  5   Close       5693 non-null   float64
#  6   Volume      5693 non-null   int64
#  7   Currency    5693 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 355.9+ KB

# %% [markdown]
# <h3 style="color: #8DEEEE;"><strong>Trực quan hóa các mối quan hệ của dữ liệu</strong></h3>

# %% [markdown]
# Trực quan dựa trên volume

# %%
plt.figure(figsize = (18,10))
plt.plot(df['Volume'])
plt.title('Volume', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Volume')

# %%
import matplotlib.pyplot as plt

# Giảm số chiều của dữ liệu và hiển thị bằng biểu đồ Boxplot
plt.boxplot(df[['Open', 'High', 'Low', 'Close']].values, labels=['Open', 'High', 'Low', 'Close'])
plt.title('Biểu đồ Boxplot giá vàng')
plt.show()

# %%
import seaborn as sns

sns.boxplot(data=df[['Open', 'High', 'Low', 'Close']])
plt.title('Phân phối giá vàng')
plt.xlabel('Giá trị')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df['Diff'] = df['Close'] - df['Open']

plt.bar(df['Date'], df['Diff'])
plt.title('Sự khác biệt giá giữa giá mở cửa và giá đóng cửa của vàng')
plt.xlabel('Ngày giao dịch')
plt.ylabel('Sự khác biệt giá')
plt.show()

# %%
fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

fig.show()

# %% [markdown]
# #### **Sử dụng biểu đồ hình nến để trực quan về giá vàng**
#
# - **Biểu đồ hình nến** (_Candlestick Chart_), hay còn thường được gọi là biểu đồ nến Nhật, mô hình nến, là một loại biểu đồ tài chính dùng để mô tả chuyển động giá của đối tượngn dựa trên mô hình giá trong quá khứ.
# - Biểu đồ hình nến có ý nghĩa vô cùng to lớn trong giao dịch tài chính nói chung và mua bán vàng nói riêng. Chỉ một biểu đồ đơn thuần sẽ cung cấp rất nhiều thông tin quan trọng về thị trường.
# - _Trục X_ nằm ngang biểu thị thời gian. Thời gian hiển thị ở trục X phụ thuộc vào khung thời gian được lựa chọn để phân tích. Nếu khung thời gian là 1D thì mỗi cây nến sẽ biểu thị mức giá dao động trong 1 ngày. 1H thì mỗi cây nến sẽ biểu thị mức giá giao động trong 1 giờ.
# - _Trục Y_ thẳng đứng biểu thị giá. Các mức giá biến động trong một khoảng thời gian nhất định.
# - Theo dataset về giá vàng đã chọn, việc lựa chọn biểu đồ nến là phù hợp, cho phép người dùng nhận ra các xu hướng, mức độ biến động và sự thay đổi trong giá cả của việc giao dịch vàng trong suốt khoảng thời gian nhất định. Bằng cách sử dụng biểu đồ hình nến, người sử dụng có thể dễ dàng so sánh giá trị cao và giá trị thấp của giá vàng trong một ngày giao dịch cụ thể.
#
#
# ##### **_Nhận xét:_**
# + Trong những năm đầu (2000 - 2005) , giá vàng khá ổn định và chỉ tăng từ từ qua từng năm cho thấy thị trường không biến động nhiều.
# + Trong 5 năm tiếp theo (2005 - 2010), đã có sự tăng trưởng mạnh và biến động không ngừng khi đồ thị có sự lên xuống không cố định, thể hiện rõ nhất là từ năm 2008 trở đi. Điều này như là một tín hiệu cho thấy thị trường sắp có sự bùng nổ trong tương lai gần.
# + Từ những năm 2010 trở đi, giá vàng đã có sự thay đổi mạnh mẽ khi vào năm 2011 đã có lúc giá vàng gần chạm tới 2000 USD, tăng trưởng gấp 1,5 lần so với những năm 2009 - 2010. Tuy nhiên, về sau thì giá vàng cũng có xu hướng giảm đi nhưng vẫn có những lần đạt giá trị cao. Xong vào tầm giữa năm 2013 - 2020, giá vàng tuy có sự tăng giảm liên tục nhưng không thể vượt quá 1500 USD nhưng cũng không ít hơn 1000 USD.
# + Xong, sang những năm 2020 trở đi, giá vàng lại tăng mạnh liên tục, đây cũng là khoảng thời gian dịch bệnh bùng phát, cho thấy yếu tố số lượng vàng giao dịch đạt con số to lớn, khiến giá vàng được đẩy lên cao.
# + Tóm lại, trong suốt 23 năm, giá vàng đã có những biến động mạnh mẽ, bùng nổ, thể hiện phần nào tình hình kinh tế, tài chính Mỹ qua từng giai đoạn, giúp người xem có những cái nhìn tổng quát hơn về một nền kinh tế lớn trên thế giới.

# %%
import matplotlib.pyplot as plt

# Giảm số chiều của dữ liệu và hiển thị bằng biểu đồ Boxplot
plt.boxplot(df[['Open', 'High', 'Low', 'Close']].values, labels=['Open', 'High', 'Low', 'Close'])
plt.title('Biểu đồ Boxplot giá vàng')
plt.show()

# %%
import plotly.express as px
fig = px.histogram(df, x = "Close", y = "Volume", marginal = "box", text_auto = True, template = "plotly_dark", hover_data  = df.columns)
fig.show()

# %%
import plotly.express as px

fig = px.treemap(df,
                 path=['Date'],
                 values='Volume',
                 color='Volume',
                 color_continuous_scale='Blues',
                 title='Biểu đồ Treemap - Volume giá vàng theo ngày')
fig.show()

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Waterfall(
    name='Volume',
    orientation='v',
    measure=['relative', 'relative', 'relative', 'relative', 'total', 'relative', 'relative', 'total'],
    x=df['Date'],
    textposition='outside',
    text=df['Volume'],
    y=df['Open'],
    connector=dict(line=dict(width=2)),
    decreasing=dict(marker_color='#FF6347'),
    increasing=dict(marker_color='#90EE90')
))

fig.update_layout(
    title='Biểu đồ Waterfall Chart - Volume giá vàng theo ngày',
    template='plotly_dark',
    xaxis_title='Ngày',
    yaxis_title='Giá mở cửa'
)

fig.show()
